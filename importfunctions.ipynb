# %%
name=input("Enter your name:")
print("Hello",name)
print(type(name))
# Out:
# Enter your name: RASHA
# Hello RASHA
# <class 'str'>

# %%
age=input("Enter your age:")
print("Age:",age)
print(type(age))
# Out:
# Enter your age: 20
# Age: 20
# <class 'str'>

# %%
n1=input("Enter first number:")
n2=input("Enter second number:")
sum=n1+n2
print("Sum=",sum)
# Out:
# Enter first number: 50
# Enter second number: 50
# Sum= 5050

# %%
n1=int(input("Enter first number:"))
n2=int(input("Enter second number:"))
sum=n1+n2
print("Sum=",sum)
# Out:
# Enter first number: 50
# Enter second number: 50
# Sum= 100

# %%
import math
number=int(input("Enter a number:"))
result=math.sqrt(number)
print("Squareroot=",result)
# Out:
# Enter a number: 10
# Squareroot= 3.1622776601683795

# %%
import math
number=float(input("Enter a number:"))
result=math.sqrt(number)
print("Squareroot=",f"{result:.2f}")
# Out:
# Enter a number: 5
# Squareroot= 2.24
