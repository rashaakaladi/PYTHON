# %%
#ACCEPT 5 STUDENTS AND SORT BY ROLL NUMBER,(ROLL NUMBER=KEY,NAME=VALUE)
r1=int(input("Enter roll number 1: "))
n1=input("Enter name 1: ")

r2=int(input("Enter roll number 2: "))
n2=input("Enter name 2: ")

r3=int(input("Enter roll number 3: "))
n3=input("Enter name 3: ")

r4=int(input("Enter roll number 4: "))
n4=input("Enter name 4: ")

r5=int(input("Enter roll number 5: "))
n5=input("Enter name 5: ")

students={r1:n1,r2:n2,r3:n3,r4:n4,r5:n5}
print("Dictionary=",students)
ascending=dict(sorted(students.items()))
descending=dict(sorted(students.items(),reverse=True))

print("Ascending order =",ascending)
print("Descending order =",descending)
# Out:
# Enter roll number 1: 103
# Enter name 1: Anu
# Enter roll number 2: 101
# Enter name 2: Fathima
# Enter roll number 3: 105
# Enter name 3: Ayisha
# Enter roll number 4: 102
# Enter name 4: Sara
# Enter roll number 5: 104
# Enter name 5: Diya
# Dictionary= {103: 'Anu', 101: 'Fathima', 105: 'Ayisha', 102: 'Sara', 104: 'Diya'}
# Ascending order = {101: 'Fathima', 102: 'Sara', 103: 'Anu', 104: 'Diya', 105: 'Ayisha'}
# Descending order = {105: 'Ayisha', 104: 'Diya', 103: 'Anu', 102: 'Sara', 101: 'Fathima'}

# %%
#MERGE TWO DICTIONARIES USING ,(update())
dic1={}

r1=int(input("Enter roll number 1: "))
n1=input("Enter name 1: ")

r2=int(input("Enter roll number 2: "))
n2=input("Enter name 2: ")

r3=int(input("Enter roll number 3: "))
n3=input("Enter name 3: ")

dic1={r1:n1,r2:n2,r3:n3}

dic2={}

r4=int(input("Enter roll number 4: "))
n4=input("Enter name 4: ")

r5=int(input("Enter roll number 5: "))
n5=input("Enter name 5: ")

dic2={r4:n4,r5:n5}

print("Dictionary 1 =",dic1)
print("Dictionary 2 =",dic2)
dic1.update(dic2)
print("Merged dictionary =",dic1)
# Out:
# Enter roll number 1: 101
# Enter name 1: Anu
# Enter roll number 2: 102
# Enter name 2: Sara
# Enter roll number 3: 103
# Enter name 3: Ayisha
# Enter roll number 4: 104
# Enter name 4: Diya
# Enter roll number 5: 105
# Enter name 5: Fathima
# Dictionary 1 = {101: 'Anu', 102: 'Sara', 103: 'Ayisha'}
# Dictionary 2 = {104: 'Diya', 105: 'Fathima'}
# Merged dictionary = {101: 'Anu', 102: 'Sara', 103: 'Ayisha', 104: 'Diya', 105: 'Fathima'}
