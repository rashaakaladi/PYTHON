# %%
#PRINT OUT ALL COLORS FROM COLOR SET1 NOT CONTAINED IN COLOR SET2
set1=set(input("Enter colors in set 1:").split(","))
set2=set(input("Enter colors in set 2:").split(","))
print("Set 1 =",set1)
print("Set 2 =",set2)
result=set1-set2
print("Colors in set 1 but not in set 2=",result)
# Out:
# Enter colors in set 1:red,green,yellow,blue
# Enter colors in set 2:green,yellow,black
# Set 1 = {'blue', 'yellow', 'red', 'green'}
# Set 2 = {'black', 'yellow', 'green'}
# Colors in set 1 but not in set 2= {'blue', 'red'}

# %%
#PRINT OUT ALL COLORS FROM COLOR SET1 AND COLOR SET2
set1=set(input("Enter colors in set 1:").split(","))
set2=set(input("Enter colors in set 2:").split(","))
print("Set 1 =",set1)
print("Set 2 =",set2)
result=set1|set2
print("Colors in set 1 and set 2=",result)
# Out:
# Enter colors in set 1:red,green,blue
# Enter colors in set 2:green,yellow,black
# Set 1 = {'blue', 'red', 'green'}
# Set 2 = {'black', 'yellow', 'green'}
# Colors in set 1 and set 2= {'black', 'red', 'yellow', 'green', 'blue'}
