# %%
#PROGRAM TO CONVERT CELSIUS TO FAHRENHEIT
c=float(input("Enter temperature in celsius:"))
f=(c*9/5)+32
print("Temperature in fahrenheit = ",f"{f:.2f}")
# Out:
# Enter temperature in celsius: 47
# Temperature in fahrenheit =  116.60

# %%
#PROGRAM TO CONVERT KILOMETERS TO MILES (1 KM = 0.62137 MILES)
km=float(input("Enter distance in kilometers:"))
miles=km*0.62137
print("Distance in miles=",f"{miles:.2f}")
# Out:
# Enter distance in kilometers: 10
# Distance in miles= 6.21
